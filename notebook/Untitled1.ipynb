# %%
# !pip install torch
# Out:
# ...
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    -- ------------------------------------- 7.9/113.8 MB 43.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 15.7/113.8 MB 39.4 MB/s eta 0:00:03
#    ------- -------------------------------- 22.5/113.8 MB 36.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 30.4/113.8 MB 36.6 MB/s eta 0:00:03
#    ------------- -------------------------- 38.5/113.8 MB 36.5 MB/s eta 0:00:03
#    --------------- ------------------------ 45.4/113.8 MB 35.8 MB/s eta 0:00:02
#    ------------------ --------------------- 53.7/113.8 MB 36.0 MB/s eta 0:00:02
#    --------------------- ------------------ 60.3/113.8 MB 35.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 65.8/113.8 MB 34.9 MB/s eta 0:00:02
#    ------------------------- -------------- 72.6/113.8 MB 34.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 80.7/113.8 MB 34.5 MB/s eta 0:00:01
# ...

# %%
import torch
import math
import random
import numpy as np
import matplotlib as pyplot

# %%
class Neuron:
    def __init__(self, nin):
        self.w =
